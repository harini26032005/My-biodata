# %%
print("Name:Harini")
print("City:Colombo")
print("Country:Sri Lanka")
print("Education:Bishop's College 2011 to 2024") 
print("Work experience:Temporary teacher at Bishop's College for2 months")
print("Skills:Communication,Leadership,Analytical skills,Time management,Technical thinking,Resilience and discipline,Collaboration")
print("Interests:Bioinformatics,Android robotics,Fusion cooking,Music theory,Animal care,sports")
# Out:
# Name:Harini
# City:Colombo
# Country:Sri Lanka
# Education:Bishop's College 2011 to 2024
# Work experience:Temporary teacher at Bishop's College for2 months
# Skills:Communication,Leadership,Analytical skills,Time management,Technical thinking,Resilience and discipline,Collaboration
# Interests:Bioinformatics,Android robotics,Fusion cooking,Music theory,Animal care,sports
